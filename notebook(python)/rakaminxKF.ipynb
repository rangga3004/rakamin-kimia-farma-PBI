# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
sns.set_palette("Blues_r")
sns.set_context("notebook")

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv(
    "/Users/mymac/Documents/#Ferizart_Studio/#Data-Analyst/Rakamin x Kimia Farma - PBI/Final Project/Output/BQ Results May 6 2025.csv"
)

# %%
df
# Out:
#        transaction_id       customer_name transaction_date product_id  \
# 0          TRX5103706  Derrick Wright III       2021-08-25      KF116
# 1          TRX5388139     Elizabeth Ramos       2020-12-29      KF116
# 2          TRX7251897       Meghan Warner       2020-02-03      KF116
# 3          TRX4943675      Steven Roberts       2022-09-09      KF116
# 4          TRX3469820     Linda Bruce DDS       2020-06-20      KF116
# ...               ...                 ...              ...        ...
# 672453     TRX2548361       Carol Shaffer       2020-09-21      KF999
# 672454     TRX8455646      Jennifer Doyle       2023-11-21      KF999
# 672455     TRX4899796      James Delacruz       2023-12-18      KF999
# 672456     TRX2779359  Christopher Campos       2022-04-14      KF999
# 672457     TRX4429449       Justin Hardin       2021-05-12      KF999
#
#                                              product_name product_category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672458 entries, 0 to 672457
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   transaction_id           672458 non-null  object
#  1   customer_name            672458 non-null  object
#  2   transaction_date         672458 non-null  object
#  3   product_id               672458 non-null  object
#  4   product_name             672458 non-null  object
#  5   product_category         672458 non-null  object
#  6   actual_price             672458 non-null  int64
#  7   discount_percentage      672458 non-null  float64
#  8   nett_sales               672458 non-null  float64
#  9   gross_profit_percentage  672458 non-null  float64
#  10  nett_profit              672458 non-null  float64
#  11  branch_id                672458 non-null  int64
#  12  branch_name              672458 non-null  object
# ...

# %%
df["actual_price"] = df.actual_price.astype(float)

# %% [markdown]
# ## Checking the Descriptive Statistics

# %%
df[
    ["actual_price", "nett_sales", "nett_profit", "rating_transaction", "rating_branch"]
].describe()
# Out:
#         actual_price     nett_sales    nett_profit  rating_transaction  \
# count  672458.000000  672458.000000  672458.000000       672458.000000
# mean   516347.954519  477607.806464  135644.141433            4.000033
# std    284547.593398  264422.423296   85148.115522            0.579164
# min      2100.000000    1785.000000     178.500000            3.000000
# 25%    296900.000000  273702.000000   56411.000000            3.500000
# 50%    523100.000000  480150.000000  142444.500000            4.000000
# 75%    757900.000000  703380.000000  211014.000000            4.500000
# max    997500.000000  997500.000000  299250.000000            5.000000
#
#        rating_branch
# count  672458.000000
# mean        4.447984
# std         0.323350
# min         3.900000
# 25%         4.200000
# 50%         4.500000
# 75%         4.700000
# max         5.000000

# %% [markdown]
# **Conclusion:**
#
# - Since there is no significant difference between the mean and the median in most numerical columns, the data distributions are likely approximately symmetrical and not heavily skewed. However, this does not guarantee the absence of outliers — a boxplot or IQR analysis would be better for confirming that.
# - In actual_price, nett_sales, and nett_profit, the standard deviations are relatively high, which indicates that the values are widely spread and prices/profits vary significantly across products.
#
# **Further visualization such as boxplots or histograms is recommended to confirm the presence of outliers and the exact shape of each distribution.**

# %% [markdown]
# ## Checking the Data Distribution

# %%
columns_to_plot = [
    "actual_price",
    "nett_sales",
    "nett_profit",
    "rating_transaction",
    "rating_branch",
]
columns_to_plot
# Out:
# ['actual_price',
#  'nett_sales',
#  'nett_profit',
#  'rating_transaction',
#  'rating_branch']

# %%
df.hist(figsize=(10, 8), bins=20, column=columns_to_plot, layout=(4, 3))
plt.tight_layout()

# %% [markdown]
# **Conclusion:**
#
# - The financial variables (actual_price, nett_sales, and nett_profit) show multimodal distributions, indicating the presence of different value segments in the data.
# - rating_transaction looks like a continuous variable between 3.0 and 5.0, with many decimal values — meaning users gave a wide variety of ratings.
# - rating_branch has fewer rating options, mostly around 4.25–4.75, showing that users tend to give scores in common rounded steps.

# %% [markdown]
# ## Checking the Data Outliers

# %%
df.plot(
    kind="box", figsize=(12, 14), column=columns_to_plot, subplots=True, layout=(4, 4)
)
plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# **Conclusion:** No Outliers
